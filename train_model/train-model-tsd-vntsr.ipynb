# %% [markdown]
# # Kiểm tra dữ liệu

# %% [markdown]
# ## Cấu hình & import

# %%
import os, glob, random, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ==== CẤU HÌNH ====
DATA_ROOT = "/kaggle/input/build-dataset-vn-tsd/vntsr_yolo"
SPLITS = ["train", "test"]

# %% [markdown]
# ## Hàm tiện ích

# %%
def list_images_labels(split):
    img_dir = f"{DATA_ROOT}/images/{split}"
    lbl_dir = f"{DATA_ROOT}/labels/{split}"
    imgs = sorted(glob.glob(f"{img_dir}/*.jpg"))
    lbls = sorted(glob.glob(f"{lbl_dir}/*.txt"))
    return imgs, lbls

def read_label_file(path):
    with open(path, "r") as f:
        lines = [line.strip().split() for line in f.readlines() if line.strip()]
    return lines

# %% [markdown]
# ## Kiểm tra tổng quan train/val

# %%
for split in SPLITS:
    imgs, lbls = list_images_labels(split)
    img_stems = {os.path.splitext(os.path.basename(p))[0] for p in imgs}
    lbl_stems = {os.path.splitext(os.path.basename(p))[0] for p in lbls}

    no_label = img_stems - lbl_stems
    orphan_lbl = lbl_stems - img_stems

    print(f"[{split.upper()}]")
    print(f"Ảnh: {len(imgs)} | Nhãn: {len(lbls)}")
    print(f"- Ảnh không có nhãn: {len(no_label)}")
    print(f"- Nhãn mồ côi: {len(orphan_lbl)}")
    print("-"*40)
# Out:
# [TRAIN]
# Ảnh: 2552 | Nhãn: 2552
# - Ảnh không có nhãn: 0
# - Nhãn mồ côi: 0
# ----------------------------------------
# [TEST]
# Ảnh: 639 | Nhãn: 639
# - Ảnh không có nhãn: 0
# - Nhãn mồ côi: 0
# ----------------------------------------

# %%
# import cv2
# import matplotlib.pyplot as plt

# # --- Hàm đọc và visualize label YOLO ---
# def visualize_yolo_image(img_path, label_path):
#     img = cv2.imread(img_path)
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     h, w, _ = img.shape

#     if not os.path.exists(label_path):
#         print(f"⚠️ Không có label cho {img_path}")
#         return

#     with open(label_path, "r") as f:
#         lines = f.readlines()

#     for line in lines:
#         cls, x, y, bw, bh = map(float, line.strip().split())
#         x_center, y_center, bw, bh = x * w, y * h, bw * w, bh * h
#         xmin = int(x_center - bw / 2)
#         ymin = int(y_center - bh / 2)
#         xmax = int(x_center + bw / 2)
#         ymax = int(y_center + bh / 2)

#         cv2.rectangle(img, (xmin, ymin), (xmax, ymax), (255, 0, 0), 2)
#         cv2.putText(img, f"{int(cls)}", (xmin, ymin - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

#     plt.imshow(img)
#     plt.axis("off")
#     plt.show()


# # --- Lấy 3 ảnh có nhãn ---
# split = "train"
# img_dir = os.path.join(DATA_ROOT, "images", split)
# lbl_dir = os.path.join(DATA_ROOT, "labels", split)

# labeled_imgs = [
#     f for f in os.listdir(lbl_dir)
#     if os.path.isfile(os.path.join(lbl_dir, f))
# ]

# print(f"🔍 Tìm thấy {len(labeled_imgs)} ảnh có nhãn trong {split}")

# for i in range(3):
#     img_id = os.path.splitext(labeled_imgs[i])[0]
#     img_path = os.path.join(img_dir, f"{img_id}.jpg")
#     label_path = os.path.join(lbl_dir, f"{img_id}.txt")

#     print(f"\n🖼️ Hiển thị: {img_id}")
#     visualize_yolo_image(img_path, label_path)

# %%
import os
import yaml

DATA_ROOT = "/kaggle/input/build-dataset-vn-tsd/vntsr_yolo"
OUT_YAML = "/kaggle/working/data.yaml"

# Lấy đường dẫn tuyệt đối của folder images/{split}
yaml_dict = {
    "path": DATA_ROOT,
    "train": os.path.join(DATA_ROOT, "images/train"),
    "val": os.path.join(DATA_ROOT, "images/test"),
    "nc": 1,
    "names": ["sign"]
}

# Ghi ra file YAML
with open(OUT_YAML, "w") as f:
    yaml.dump(yaml_dict, f, sort_keys=False)

print(f"✅ Tạo file data.yaml tại {OUT_YAML}")
# Out:
# ✅ Tạo file data.yaml tại /kaggle/working/data.yaml

# %% [markdown]
# # Training model

# %% [markdown]
# ## Định nghĩa hàm train_and_log()

# %%
# !pip install -q ultralytics --no-deps
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.1 MB/s eta 0:00:00

# %%
import time
import pandas as pd
from ultralytics import YOLO

def train_and_log(model_name, base_weights, data_yaml, save_dir, 
                  epochs=100, imgsz=640, batch=32):
    """
    Huấn luyện YOLO model và lưu lại kết quả huấn luyện cơ bản.
    
    Args:
        model_name (str): Tên mô hình (vd: YOLOv8n)
        base_weights (str): Đường dẫn file .pt gốc
        data_yaml (str): Đường dẫn file data.yaml
        save_dir (str): Thư mục lưu project YOLO
        epochs (int): Số epoch huấn luyện
        imgsz (int): Kích thước ảnh
        batch (int): Kích thước batch
        
    Returns:
        dict: Gồm các chỉ số mAP, Precision, Recall, thời gian huấn luyện, ...
    """
    start_time = time.time()
    
    model = YOLO(base_weights)
    results = model.train(
        data=data_yaml,
        epochs=epochs,
        imgsz=imgsz,
        batch=batch,
        mosaic=1.0,
        scale=0.5,
        copy_paste=0.1,
        hsv_h=0.015, hsv_s=0.7, hsv_v=0.4,
        project=save_dir,
        name=model_name,
        workers=4,
        patience=10,
        verbose=False
    )
    
    elapsed = time.time() - start_time
    
    # Lấy metrics từ YOLO
    metrics = results.results_dict
    metrics.update({
        "Model": model_name,
        "Epochs": epochs,
        "ImgSize": imgsz,
        "Batch": batch,
        "TrainTime(min)": round(elapsed/60, 2)
    })
    
    print(f"✅ Hoàn tất {model_name} | "
          f"mAP50={metrics.get('metrics/mAP50(B)', 0):.4f} | "
          f"Precision={metrics.get('metrics/precision(B)', 0):.4f} | "
          f"Recall={metrics.get('metrics/recall(B)', 0):.4f} | "
          f"⏱ {elapsed/60:.2f} phút")
    
    return metrics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## Chuẩn bị file data.yaml

# %% [markdown]
# ## Huấn luyện 3 model baseline

# %%
import pandas as pd

project_dir = "/kaggle/working/yolo_runs"

# 3 mô hình baseline
models = {
    "YOLOv5n": "yolov5n.pt",
    "YOLOv8n": "yolov8n.pt",
    "YOLO11n": "yolo11n.pt"
}

train_logs = []

for name, weights in models.items():
    print(f"\n Training {name} ...")
    m = train_and_log(
        model_name=name,
        base_weights=weights,
        data_yaml=OUT_YAML,
        save_dir=project_dir,
        epochs=30,
        imgsz=640,
        batch=32
    )
    train_logs.append(m)

# Lưu lại kết quả
df_results = pd.DataFrame(train_logs)
df_results.to_csv(f"{project_dir}/train_summary.csv", index=False)
print("\n✅ Saved summary:", f"{project_dir}/train_summary.csv")
display(df_results)
# Out:
#  Training YOLOv5n ...
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5nu.pt to 'yolov5nu.pt': 100% ━━━━━━━━━━━━ 5.3MB 70.4MB/s 0.1s
# Ultralytics 8.3.228 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.1, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=YOLOv5n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_runs/YOLOv5n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1760  ultralytics.nn.modules.conv.Conv             [3, 16, 6, 2, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      4800  ultralytics.nn.modules.block.C3              [32, 32, 1]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     29184  ultralytics.nn.modules.block.C3              [64, 64, 2]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  14                  -1  1      8320  ultralytics.nn.modules.conv.Conv             [128, 64, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     22912  ultralytics.nn.modules.block.C3              [128, 64, 1, False]
#  18                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1     74496  ultralytics.nn.modules.block.C3              [128, 128, 1, False]
#  21                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  24        [17, 20, 23]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv5n summary: 153 layers, 2,508,659 parameters, 2,508,643 gradients
#
# Transferred 391/427 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 71.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 53.3±19.5 MB/s, size: 331.5 KB)
# train: Scanning /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels/train... 2552 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2552/2552 262.4it/s 9.7s
# WARNING ⚠️ train: Cache directory /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 37.5±26.2 MB/s, size: 233.0 KB)
# val: Scanning /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels/test... 639 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 639/639 262.8it/s 2.4s
# WARNING ⚠️ val: Cache directory /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels is not writable, cache not saved.
# Plotting labels to /kaggle/working/yolo_runs/YOLOv5n/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 69 weight(decay=0.0), 76 weight(decay=0.0005), 75 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/yolo_runs/YOLOv5n
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      4.04G      1.225      2.015     0.9455         78        640: 100% ━━━━━━━━━━━━ 80/80 2.5it/s 32.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.0it/s 4.9s
#                    all        639       1645      0.959      0.214      0.611      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      4.75G      1.128      1.032     0.9116        107        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.873      0.759      0.849      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      5.08G        1.1     0.8416     0.9034        122        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.6s
#                    all        639       1645      0.866       0.78      0.863      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30       5.1G      1.071     0.7608     0.8966        113        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.869      0.785      0.867      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      5.11G      1.037     0.6938     0.8853        102        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.896       0.83      0.905      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      5.13G      1.014     0.6482     0.8827        110        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.4s
#                    all        639       1645      0.885      0.846      0.913      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      5.14G      1.001     0.6245      0.879        108        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.4s
#                    all        639       1645      0.868       0.84      0.901      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      5.16G     0.9912     0.6123     0.8771         77        640: 100% ━━━━━━━━━━━━ 80/80 2.5it/s 31.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.1it/s 3.2s
#                    all        639       1645      0.871      0.836      0.908       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      5.17G     0.9693     0.5841     0.8678        111        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.923      0.866      0.936      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      5.19G      0.947     0.5621     0.8666        115        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645      0.934      0.862      0.944      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30       5.2G     0.9359     0.5518      0.862        128        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.4s
#                    all        639       1645      0.901      0.869      0.926      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      5.21G     0.9284     0.5414     0.8613        109        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645      0.944      0.873      0.952      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      5.23G     0.9096     0.5282     0.8576        123        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645      0.918      0.906      0.952      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      5.24G     0.8907     0.5083      0.857        136        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645      0.927      0.884      0.945      0.693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      5.26G     0.8935     0.5051      0.856         95        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.4s
#                    all        639       1645      0.941      0.889      0.953      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      5.27G     0.8888     0.5052     0.8528        124        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.942      0.906      0.964        0.7
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      5.29G     0.8707      0.492     0.8485         99        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.4s
#                    all        639       1645      0.942      0.915      0.969      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30       5.3G     0.8565     0.4842     0.8479        107        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.939      0.919      0.964      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      5.31G     0.8573     0.4745      0.847        129        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 31.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.4s
#                    all        639       1645      0.946      0.926      0.972      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      5.33G     0.8438     0.4674     0.8437        122        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.4s
#                    all        639       1645      0.944      0.921      0.965      0.721
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      5.34G     0.8419     0.4632     0.8481         59        640: 100% ━━━━━━━━━━━━ 80/80 2.5it/s 31.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.925      0.913      0.959      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      5.36G     0.8205     0.4449     0.8397         59        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.936      0.929      0.969      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      5.37G     0.8145     0.4294     0.8365         65        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.957      0.925      0.972      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      5.38G     0.8024     0.4279      0.837         71        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.961      0.928      0.975      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30       5.4G     0.7932     0.4159     0.8348         63        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.4s
#                    all        639       1645      0.942      0.929      0.971      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      5.41G     0.7834     0.4093     0.8308         44        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.957      0.939      0.978      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      5.43G     0.7653     0.3947     0.8296         60        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.964      0.934      0.978      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      5.44G      0.764     0.3924     0.8337         51        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.959      0.941      0.978      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      5.46G     0.7513     0.3827     0.8293         46        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645       0.97      0.935       0.98       0.76
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      5.47G     0.7387     0.3737     0.8255         54        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.968      0.938       0.98      0.765
#
# 30 epochs completed in 0.281 hours.
# Optimizer stripped from /kaggle/working/yolo_runs/YOLOv5n/weights/last.pt, 5.3MB
# Optimizer stripped from /kaggle/working/yolo_runs/YOLOv5n/weights/best.pt, 5.3MB
#
# Validating /kaggle/working/yolo_runs/YOLOv5n/weights/best.pt...
# Ultralytics 8.3.228 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv5n summary (fused): 84 layers, 2,503,139 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.7s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all        639       1645      0.968      0.938       0.98      0.764
# Speed: 0.1ms preprocess, 1.4ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /kaggle/working/yolo_runs/YOLOv5n
# ✅ Hoàn tất YOLOv5n | mAP50=0.9803 | Precision=0.9676 | Recall=0.9380 | ⏱ 17.70 phút
#
#  Training YOLOv8n ...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 75.8MB/s 0.1s
# Ultralytics 8.3.228 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.1, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=YOLOv8n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_runs/YOLOv8n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 129 layers, 3,011,043 parameters, 3,011,027 gradients
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 438.3±242.0 MB/s, size: 238.5 KB)
# train: Scanning /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels/train... 2552 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2552/2552 712.3it/s 3.6s
# WARNING ⚠️ train: Cache directory /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 249.8±112.3 MB/s, size: 307.7 KB)
# val: Scanning /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels/test... 639 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 639/639 647.0it/s 1.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels is not writable, cache not saved.
# Plotting labels to /kaggle/working/yolo_runs/YOLOv8n/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/yolo_runs/YOLOv8n
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      4.07G      1.201      1.935     0.9426         78        640: 100% ━━━━━━━━━━━━ 80/80 2.5it/s 31.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.5it/s 4.0s
#                    all        639       1645          1     0.0521      0.369      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30         5G      1.116      1.021     0.9078        107        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.6it/s 3.8s
#                    all        639       1645      0.874      0.747      0.845      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30         5G      1.092     0.8265     0.9011        122        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.858      0.757      0.853       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30         5G      1.065     0.7471     0.9024        113        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.833      0.774      0.838      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30         5G       1.03     0.6723     0.8891        102        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.884      0.818      0.893      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30         5G      1.006     0.6399     0.8836        110        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.4s
#                    all        639       1645      0.842      0.834      0.892      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30         5G     0.9876     0.6085     0.8783        108        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.3s
#                    all        639       1645      0.892      0.837      0.914      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30         5G     0.9775     0.6046     0.8796         77        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.896      0.847      0.918       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30         5G     0.9584     0.5727     0.8699        111        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.3s
#                    all        639       1645      0.891      0.862      0.922       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      5.01G      0.948     0.5539     0.8725        115        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.924       0.89      0.947      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      5.03G     0.9262     0.5403     0.8641        128        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.916      0.891      0.941      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      5.04G     0.9178     0.5338     0.8631        109        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.911      0.904       0.95       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      5.06G     0.9011     0.5124     0.8609        123        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.932      0.896      0.955       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      5.08G     0.8826     0.4943     0.8589        136        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.937      0.908      0.961      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      5.09G     0.8806     0.4924     0.8586         95        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645      0.937      0.921      0.966      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      5.11G     0.8674     0.4879     0.8525        124        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645      0.923      0.907      0.955      0.708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      5.13G     0.8567     0.4788     0.8514         99        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645      0.944      0.918      0.964      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      5.14G     0.8454      0.472     0.8493        107        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.943      0.917      0.962      0.701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      5.16G     0.8413     0.4635     0.8477        129        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645      0.933       0.93       0.97      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      5.18G     0.8367     0.4617     0.8475        122        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.948      0.921      0.974      0.738
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30       5.2G      0.824     0.4504     0.8506         59        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 31.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.943      0.923       0.97      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      5.21G     0.8068     0.4333     0.8433         59        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.936      0.908       0.96      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      5.23G     0.8079     0.4182     0.8424         65        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 28.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.4s
#                    all        639       1645      0.956      0.927      0.977      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      5.25G     0.7871     0.4131     0.8391         71        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.4s
#                    all        639       1645      0.955      0.936      0.977      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      5.26G     0.7799     0.4031     0.8383         63        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.948      0.939      0.977      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      5.28G     0.7737     0.3985     0.8357         44        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.957      0.928      0.976      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30       5.3G     0.7555     0.3803     0.8332         60        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.966      0.939      0.981      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      5.31G     0.7602     0.3826      0.838         51        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 28.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.962      0.936      0.981      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      5.33G     0.7384     0.3744     0.8312         46        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        639       1645       0.97      0.939      0.982      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      5.35G     0.7307     0.3638     0.8288         54        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.962      0.945      0.982      0.768
#
# 30 epochs completed in 0.273 hours.
# Optimizer stripped from /kaggle/working/yolo_runs/YOLOv8n/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/yolo_runs/YOLOv8n/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/yolo_runs/YOLOv8n/weights/best.pt...
# Ultralytics 8.3.228 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.3it/s 4.4s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all        639       1645      0.962      0.945      0.982      0.767
# Speed: 0.1ms preprocess, 1.3ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /kaggle/working/yolo_runs/YOLOv8n
# ✅ Hoàn tất YOLOv8n | mAP50=0.9824 | Precision=0.9616 | Recall=0.9453 | ⏱ 16.66 phút
#
#  Training YOLO11n ...
# Ultralytics 8.3.228 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.1, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=YOLO11n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_runs/YOLO11n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 347.6±236.4 MB/s, size: 238.5 KB)
# train: Scanning /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels/train... 2552 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2552/2552 695.6it/s 3.7s
# WARNING ⚠️ train: Cache directory /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 224.5±95.2 MB/s, size: 307.7 KB)
# val: Scanning /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels/test... 639 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 639/639 601.4it/s 1.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/build-dataset-vn-tsd/vntsr_yolo/labels is not writable, cache not saved.
# Plotting labels to /kaggle/working/yolo_runs/YOLO11n/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/yolo_runs/YOLO11n
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      4.55G       1.22      2.033     0.9592         78        640: 100% ━━━━━━━━━━━━ 80/80 2.5it/s 32.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.6it/s 3.9s
#                    all        639       1645      0.987     0.0453      0.281      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      5.29G      1.127      1.075     0.9262        107        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.6it/s 3.8s
#                    all        639       1645      0.875      0.713      0.824      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      5.29G      1.116     0.8841     0.9202        122        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.8s
#                    all        639       1645      0.804       0.72      0.773        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      5.29G      1.068     0.7656     0.9136        113        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.851      0.753      0.841      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      5.29G      1.051     0.7013     0.9022        102        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.868      0.793      0.871      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      5.29G      1.016     0.6641     0.8964        110        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.871      0.848      0.911      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      5.29G      1.006     0.6345     0.8906        108        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.869      0.835      0.904      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      5.29G     0.9984     0.6242     0.8911         77        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.903      0.846      0.923      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      5.29G     0.9762     0.5953     0.8806        111        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.6it/s 3.8s
#                    all        639       1645      0.905      0.845      0.919      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      5.29G     0.9644     0.5741     0.8808        115        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.6s
#                    all        639       1645      0.861      0.859      0.916      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      5.29G      0.944     0.5557     0.8744        128        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.6it/s 3.8s
#                    all        639       1645      0.901      0.868      0.926      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      5.29G     0.9357     0.5469     0.8733        109        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.887      0.852      0.923      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      5.29G     0.9114     0.5282     0.8684        123        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.915      0.888      0.946      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      5.29G     0.8949     0.5083     0.8676        136        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.8s
#                    all        639       1645      0.911      0.907      0.955      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      5.29G      0.895     0.5083      0.868         95        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.8s
#                    all        639       1645      0.909      0.915      0.956      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30       5.3G     0.8966     0.5077     0.8626        124        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.6it/s 3.8s
#                    all        639       1645      0.923      0.909      0.954      0.701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      5.32G     0.8725     0.4957     0.8575         99        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.915      0.904      0.951      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      5.33G     0.8609     0.4871     0.8575        107        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.935      0.905      0.954      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      5.35G     0.8616     0.4821     0.8563        129        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.6it/s 3.9s
#                    all        639       1645      0.943      0.914      0.963      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      5.36G     0.8498     0.4745      0.852        122        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645       0.94      0.918      0.964      0.721
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      5.38G      0.839     0.4633     0.8582         59        640: 100% ━━━━━━━━━━━━ 80/80 2.6it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.5it/s 4.0s
#                    all        639       1645      0.924      0.908      0.953      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      5.39G     0.8231     0.4492     0.8497         59        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.8s
#                    all        639       1645      0.923      0.903      0.954       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30       5.4G     0.8262     0.4359     0.8492         65        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        639       1645      0.941      0.935      0.971      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      5.42G     0.8057     0.4245      0.846         71        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.6s
#                    all        639       1645      0.959      0.915      0.968      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      5.43G     0.8004     0.4189      0.844         63        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.952      0.929       0.97      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      5.45G     0.7904     0.4096     0.8414         44        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645       0.96      0.927      0.973      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      5.46G     0.7681     0.3951     0.8382         60        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 28.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.952      0.936      0.975      0.751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      5.48G     0.7689     0.3953     0.8424         51        640: 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.958      0.941      0.977      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      5.49G     0.7538     0.3859     0.8358         46        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        639       1645      0.956      0.943      0.976      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      5.51G     0.7432     0.3742      0.834         54        640: 100% ━━━━━━━━━━━━ 80/80 2.8it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        639       1645      0.953      0.944      0.976      0.762
#
# 30 epochs completed in 0.280 hours.
# Optimizer stripped from /kaggle/working/yolo_runs/YOLO11n/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/yolo_runs/YOLO11n/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/yolo_runs/YOLO11n/weights/best.pt...
# Ultralytics 8.3.228 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.3it/s 4.3s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all        639       1645      0.953      0.944      0.976      0.762
# Speed: 0.1ms preprocess, 1.4ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /kaggle/working/yolo_runs/YOLO11n
# ✅ Hoàn tất YOLO11n | mAP50=0.9763 | Precision=0.9527 | Recall=0.9438 | ⏱ 17.08 phút
#
# ✅ Saved summary: /kaggle/working/yolo_runs/train_summary.csv
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0              0.967586           0.937994          0.980304
# 1              0.961590           0.945289          0.982402
# 2              0.952749           0.943822          0.976296
#
#    metrics/mAP50-95(B)   fitness    Model  Epochs  ImgSize  Batch  \
# 0             0.764414  0.764414  YOLOv5n      30      640     32
# 1             0.767366  0.767366  YOLOv8n      30      640     32
# 2             0.761879  0.761879  YOLO11n      30      640     32
#
#    TrainTime(min)
# 0           17.70
# 1           16.66
# 2           17.08
